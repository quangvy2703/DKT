# %%
import pandas as pd
test = pd.read_csv('example_test.csv')

# %%
user_str = [str(user) + '.csv' for user in  list(test['user_id'])]

# %%
import os
train = os.listdir('data')

# %%
train
# Out:
# ['1746545161.csv',
#  '419086473.csv',
#  '1311633874.csv',
#  '1859901035.csv',
#  '2117822764.csv',
#  '863752653.csv',
#  '1624739561.csv',
#  '1265933052.csv',
#  '1968618505.csv',
#  '1838439549.csv',
#  '856218017.csv',
#  '1087227436.csv',
#  '2068371695.csv',
#  '214126208.csv',
#  '906728518.csv',
#  '646659026.csv',
#  '1355998503.csv',
#  '480394046.csv',
#  '2075908770.csv',
#  '181220770.csv',
#  '1732196633.csv',
#  '211392822.csv',
#  '848186729.csv',
#  '577896059.csv',
#  '1991409372.csv',
#  '633298835.csv',
#  '1962595540.csv',
#  '1974987748.csv',
#  '1374488711.csv',
#  '99422545.csv',
#  '1505617929.csv',
#  '751333792.csv',
#  '153726027.csv',
#  '47327778.csv',
#  '1302754788.csv',
#  '397495678.csv',
#  '239935077.csv',
#  '626326007.csv',
#  '1199355214.csv',
#  '254103995.csv',
#  '931535138.csv',
#  '1168661041.csv',
#  '2087420096.csv',
#  '1662887709.csv',
#  '758801093.csv',
#  '123731530.csv',
#  '768094599.csv',
#  '467862398.csv',
# ...

# %%
user_str
# Out:
# ['275030867.csv',
#  '554169193.csv',
#  '1720860329.csv',
#  '288641214.csv',
#  '1728340777.csv',
#  '1364159702.csv',
#  '1521618396.csv',
#  '1317245193.csv',
#  '1700555100.csv',
#  '998511398.csv',
#  '1422853669.csv',
#  '1096784725.csv',
#  '1096784725.csv',
#  '1096784725.csv',
#  '1096784725.csv',
#  '385471210.csv',
#  '1202386221.csv',
#  '2018567473.csv',
#  '275030867.csv',
#  '1233875513.csv',
#  '1233875513.csv',
#  '1233875513.csv',
#  '891955351.csv',
#  '1981166446.csv',
#  '1981166446.csv',
#  '1981166446.csv',
#  '1637273633.csv',
#  '2030979309.csv',
#  '2030979309.csv',
#  '2030979309.csv',
#  '319060572.csv',
#  '319060572.csv',
#  '319060572.csv',
#  '319060572.csv',
#  '288641214.csv',
#  '98059812.csv',
#  '674533997.csv',
#  '555691277.csv',
#  '1317245193.csv',
#  '1202386221.csv',
#  '775113212.csv',
#  '775113212.csv',
#  '775113212.csv',
#  '775113212.csv',
#  '1219481379.csv',
#  '275030867.csv',
#  '1521618396.csv',
#  '1148874033.csv',
# ...

# %%
for user in set(user_str):
    if user in train:
        print("In")
    else:
        print("Out")
# Out:
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# Out
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
# In
